# %%
from cst.datos import cargar_caudal_genil, cargar_lluvia_genil, cargar_piezometria
import matplotlib.pyplot as plt

# %%
genil_nuevo = cargar_caudal_genil()

# %%
genil_nuevo
# Out:
# fecha
# 2018-01-01     4.552541
# 2018-01-02     4.268376
# 2018-01-03     4.170236
# 2018-01-04     3.842428
# 2018-01-05     3.763615
#                 ...
# 2026-05-13    10.936493
# 2026-05-14    10.692106
# 2026-05-15    10.867303
# 2026-05-16     9.904299
# 2026-05-17          NaN
# Freq: D, Name: caudal_A20_GENIL_TOCON, Length: 3059, dtype: float64

# %%
genil_historico = cargar_caudal_genil(source="CEDEX")

# %%
genil_historico
# Out:
# fecha
# 1913-01-01      NaN
# 1913-01-02      NaN
# 1913-01-03      NaN
# 1913-01-04      NaN
# 1913-01-05      NaN
#               ...
# 2021-09-26    0.479
# 2021-09-27    0.403
# 2021-09-28    0.346
# 2021-09-29    0.336
# 2021-09-30    0.336
# Freq: D, Name: caudal_ROEA_5020, Length: 39720, dtype: float64

# %%
lluvia_nueva = cargar_lluvia_genil(source="SAIH")

# %%
lluvia_nueva
# Out:
# fecha
# 2018-01-01    0.0
# 2018-01-02    0.2
# 2018-01-03    0.0
# 2018-01-04    0.1
# 2018-01-05    0.0
#              ...
# 2026-05-13    0.0
# 2026-05-14    0.0
# 2026-05-15    0.0
# 2026-05-16    0.0
# 2026-05-17    NaN
# Freq: D, Name: lluvia_A20_202, Length: 3059, dtype: float64

# %%
lluvia_historica = cargar_lluvia_genil(source="CEDEX")

# %%
lluvia_historica
# Out:
# fecha
# 1969-12-01     69.3
# 1970-01-01    240.3
# 1970-02-01     19.8
# 1970-03-01     50.1
# 1970-04-01     37.5
#               ...
# 2021-05-01      NaN
# 2021-06-01      NaN
# 2021-07-01      NaN
# 2021-08-01      NaN
# 2021-09-01      NaN
# Name: precip_mensual_evap_5001, Length: 475, dtype: float64

# %%
piezo = cargar_piezometria(codigo="PZ0267014")

# %%
piezo
# Out:
# fecha
# 1985-04-23    690.923
# 1985-11-16    679.233
# 1986-04-17    684.423
# 1986-10-22    675.263
# 1987-04-15    682.293
#                ...
# 2024-03-13    698.763
# 2024-05-24    698.163
# 2024-07-05    696.693
# 2024-09-05    689.963
# 2024-11-12    694.463
# Name: cota_PZ0267014, Length: 165, dtype: float64

# %%
plt.hist(piezo.index.diff().days.values)
# Out:
# (array([156.,   4.,   3.,   0.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([  26. ,  208.5,  391. ,  573.5,  756. ,  938.5, 1121. , 1303.5,
#         1486. , 1668.5, 1851. ]),
#  <BarContainer object of 10 artists>)
